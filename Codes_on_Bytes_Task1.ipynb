# %%
#Import all reqired Libraries
import requests
import pandas as pd

# %%
#Call API and data through API
api_url = "https://api.binance.com/api/v3/ticker/24hr"
response = requests.get(api_url)

# %%
#Put If-else statement on called API
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    df.to_csv("binance_data.csv", index=False)  # This will create a CSV file named "binance_data.csv" in the current directory
else:
    print("API request to Binance failed")

# %%
#Assign variable to CSV file
data=pd.read_csv("binance_data.csv")

# %%
data
# Out:
#         symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0       ETHBTC    -0.000140              -0.251          0.055128
# 1       LTCBTC    -0.000034              -1.537          0.002182
# 2       BNBBTC     0.000014               0.187          0.007444
# 3       NEOBTC    -0.000003              -1.226          0.000242
# 4      QTUMETH     0.000006               0.435          0.001388
# ...        ...          ...                 ...               ...
# 2311  LEVERTRY    -0.001580              -4.204          0.036795
# 2312  LTCFDUSD    -0.320000              -0.516         62.075206
# 2313  ADAFDUSD    -0.001000              -0.403          0.246164
# 2314  RUNETUSD     0.042000               2.743          1.542859
# 2315    TRBTRY   -54.000000              -3.295       1606.973013
#
#       prevClosePrice    lastPrice       lastQty     bidPrice       bidQty  \
# 0           0.055710     0.055580  1.072000e-01     0.055570       8.4882
# ...
